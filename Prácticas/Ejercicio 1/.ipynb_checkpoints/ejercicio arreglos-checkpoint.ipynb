# %% [markdown]
# Actividad: Se otorga el archivo Ising 100.csv el cual contiene información sobre un experimento computacional del modelo de Ising, contiene 5 columnas las cuales representan: Temperatura, Energía, Magnetización, Capacidad Calorífica y Susceptibilidad Magnética. Tienen que abrir, extraer los datos y guardar en 5 listas distintas cada columna.

# %%
archivo = open("Ising 100.csv", "r")
lista = []
for i in archivo.readlines():
    lista.append(i)
lista2 = []
for i in lista:
    lista2.append(i.split())

# %%
#en la lista2 hay listas por cada renglón del archivo, cada una con 5 elementos. Mi idea es seleccionar cada uno usando [0], [1], etc

# %%
T = []
E = []
M = []
CC = []
SC = []
for i in lista2:
    T.append(float(i[0])) #la clave fue recordar que cuando se usan iteradores en listas, estos no representan números sino renglones
    E.append(float(i[1])) #por eso era incorrecto escribir "float(lista2[i][n])", y con "i[n]" sí funciona.
    M.append(float(i[2]))
    CC.append(float(i[3]))
    SC.append(float(i[4]))

# %%
float(lista2[0][0])
# Out:
# 0.1

# %%
lista2
# Out:
# [['0.1', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.11', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.12', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.13', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.14', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.15', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.16', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.17', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.18', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.19', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.2', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.21', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.22', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.23', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.24', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.25', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.26', '-4.0', '1.0', '0.0', '0.0'],
#  ['0.27',
#   '-3.9999839999999995',
#   '0.9999979999999999',
#   '34.85256350753423',
#   '0.14703425229741002'],
#  ['0.28',
#   '-3.9999919999999998',
#   '0.999999',
#   '16.285611989156553',
#   '0.07124955245255993'],
#  ['0.29',
#   '-3.9999839999999995',
# ...

# %%
T
# Out:
# [0.1,
#  0.11,
#  0.12,
#  0.13,
#  0.14,
#  0.15,
#  0.16,
#  0.17,
#  0.18,
#  0.19,
#  0.2,
#  0.21,
#  0.22,
#  0.23,
#  0.24,
#  0.25,
#  0.26,
#  0.27,
#  0.28,
#  0.29,
#  0.3,
#  0.31,
#  0.32,
#  0.33,
#  0.34,
#  0.35,
#  0.36,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.46,
#  0.47,
#  0.48,
#  0.49,
#  0.5,
#  0.51,
#  0.52,
#  0.53,
#  0.54,
#  0.55,
#  0.56,
#  0.57,
#  0.58,
#  0.59,
#  0.6,
#  0.61,
#  0.62,
#  0.63,
#  0.64,
#  0.65,
#  0.66,
#  0.67,
#  0.68,
#  0.69,
#  0.7,
#  0.71,
#  0.72,
#  0.73,
#  0.74,
#  0.75,
#  0.76,
#  0.77,
#  0.78,
#  0.79,
#  0.8,
#  0.81,
#  0.82,
#  0.83,
#  0.84,
#  0.85,
#  0.86,
#  0.87,
#  0.88,
#  0.89,
#  0.9,
#  0.91,
#  0.92,
#  0.93,
#  0.94,
#  0.95,
#  0.96,
#  0.97,
#  0.98,
#  0.99,
#  1.0,
#  1.01,
#  1.02,
#  1.03,
#  1.04,
#  1.05,
#  1.06,
#  1.07,
#  1.08,
#  1.09,
#  1.1,
#  1.11,
#  1.12,
#  1.13,
#  1.14,
#  1.15,
#  1.16,
#  1.17,
#  1.18,
#  1.19,
#  1.2,
#  1.21,
# ...

# %% [markdown]
# Actividad: Generen dos listas las cuales sean el dominio y la función Sin(x) evaluada en ese dominio. Después guarden en un archivo .csv o .txt ambas listas.

# %%
import numpy as np
dom = np.linspace(-10,10,100)
f = np.sin(dom)

# %%
range(2)
# Out:
# range(0, 2)
